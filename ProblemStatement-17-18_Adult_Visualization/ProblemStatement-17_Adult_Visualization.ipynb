# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
col_names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
             'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
c = pd.read_csv("Cleavland.csv", names=col_names, na_values="?", sep=",")
h = pd.read_csv("hung.csv", names=col_names, na_values="?", sep=",")
s = pd.read_csv("Switzerland.csv", names=col_names, na_values="?", sep=",")

# %%
df = pd.concat([c,s,h])

# %%
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 289  52.0  1.0  4.0     160.0  331.0  0.0      0.0     94.0    1.0      2.5
# 290  54.0  0.0  3.0     130.0  294.0  0.0      1.0    100.0    1.0      0.0
# 291  56.0  1.0  4.0     155.0  342.0  1.0      0.0    150.0    1.0      3.0
# 292  58.0  0.0  2.0     180.0  393.0  0.0      0.0    110.0    1.0      1.0
# 293  65.0  1.0  4.0     130.0  275.0  0.0      1.0    115.0    1.0      1.0
#
#      slope   ca  thal  target
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720 entries, 0 to 293
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       720 non-null    float64
#  1   sex       720 non-null    float64
#  2   cp        720 non-null    float64
#  3   trestbps  717 non-null    float64
#  4   chol      697 non-null    float64
#  5   fbs       637 non-null    float64
#  6   restecg   718 non-null    float64
#  7   thalach   718 non-null    float64
#  8   exang     718 non-null    float64
#  9   oldpeak   714 non-null    float64
#  10  slope     513 non-null    float64
#  11  ca        307 non-null    float64
#  12  thal      400 non-null    float64
#  13  target    720 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 84.4 KB

# %%
df.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      3
# chol         23
# fbs          83
# restecg       2
# thalach       2
# exang         2
# oldpeak       6
# slope       207
# ca          413
# thal        320
# target        0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (298, 14)

# %%
def draw_box(df, col):
    sns.boxplot(df[col])
    plt.title(f"Box plot {col}")  # Use f-string to include variable value in the title

for col in df.columns:
    draw_box(df, col)  # Pass each column name to the draw_box function
    plt.show()  # Display each plot separately
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["age"],bins=20,kde=True)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram for age")
# Out:
# Text(0.5, 1.0, 'Histogram for age')

# %%
df.reset_index(drop=True,inplace=True)
sns.lineplot(x="age",y="trestbps",data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x='cp',y='age',data=df)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="sex",y="chol",data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="age",y="cp",hue="chol",data=df,s=100)
# Out:
# <AxesSubplot:xlabel='age', ylabel='cp'>

# %%
df["sex"].value_counts().plot.pie(autopct="%1.1f%%",colors=["skyblue","salmon"])
# Out:
# <AxesSubplot:ylabel='sex'>
