# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("movies_metadata.csv",low_memory=False);
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.shape
# Out:
# (45466, 24)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (693, 24)

# %%
df.head()
# Out:
#      adult                              belongs_to_collection    budget  \
# 9    False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 68   False  {'id': 43563, 'name': 'Friday Collection', 'po...   3500000
# 69   False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...  19000000
# 153  False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...   2000000
# 178  False  {'id': 286162, 'name': 'Power Rangers Collecti...  15000000
#
#                                                 genres  \
# 9    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 68                      [{'id': 35, 'name': 'Comedy'}]
# 69   [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 153                     [{'id': 35, 'name': 'Comedy'}]
# 178  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                               homepage     id    imdb_id  \
# 9         http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# ...

# %%
df.isnull().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
df["original_language"].unique()
# Out:
# array(['en', 'wo', 'it', 'ja', 'cn', 'da', 'zh', 'ko', 'fr', 'ru', 'pt',
#        'es', 'th', 'sv', 'no', 'fi', 'hi', 'nl', 'id', 'de', 'ar'],
#       dtype=object)

# %%
df_en = df[df["original_language"] == "en"]
df_en.head()
# Out:
#      adult                              belongs_to_collection    budget  \
# 9    False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 68   False  {'id': 43563, 'name': 'Friday Collection', 'po...   3500000
# 69   False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...  19000000
# 153  False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...   2000000
# 178  False  {'id': 286162, 'name': 'Power Rangers Collecti...  15000000
#
#                                                 genres  \
# 9    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 68                      [{'id': 35, 'name': 'Comedy'}]
# 69   [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 153                     [{'id': 35, 'name': 'Comedy'}]
# 178  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                               homepage     id    imdb_id  \
# 9         http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# ...

# %%
df_wo = df[df["original_language"] == "wo"]
df_wo.head()
# Out:
#      adult                              belongs_to_collection budget  \
# 753  False  {'id': 303969, 'name': 'Martin Scorsese’s Worl...      0
#
#                                                 genres  \
# 753  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                               homepage     id    imdb_id  \
# 753  http://worldcinemafoundation.org/films/touki-b...  77771  tt0070820
#
#     original_language original_title  \
# 753                wo    Touki-Bouki
#
#                                               overview  ... release_date  \
# 753  A cowherd with a skull-mounted motorcycle and ...  ...   1973-07-01
#
#     revenue runtime                                   spoken_languages  \
# 753     0.0    85.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
#
#        status                   tagline        title  video vote_average  \
# 753  Released  The Journey of the Hyena  Touki Bouki  False          7.3
#
#     vote_count
# 753       10.0
# ...

# %%
df_it = df[df["original_language"] == "it"]
df_it.head()
# Out:
#       adult                              belongs_to_collection   budget  \
# 1159  False  {'id': 48317, 'name': 'The Man With No Name Co...  1200000
# 4197  False  {'id': 441439, 'name': 'Alienation Trilogy', '...        0
#
#                                genres  \
# 1159  [{'id': 37, 'name': 'Western'}]
# 4197    [{'id': 18, 'name': 'Drama'}]
#
#                                                homepage     id    imdb_id  \
# 1159  http://www.mgm.com/#/our-titles/766/The-Good,-...    429  tt0060196
# 4197               http://www.imdb.com/title/tt0054130/  41050  tt0054130
#
#      original_language                   original_title  \
# 1159                it  Il buono, il brutto, il cattivo
# 4197                it                         La notte
#
#                                                overview  ... release_date  \
# 1159  While the Civil War rages between the Union an...  ...   1966-12-23
# 4197  A married couple attend a bourgeois party and ...  ...   1961-01-23
#
# ...

# %%
df_merge_ew = pd.concat([df_en,df_wo])
df_merge_ew
# Out:
#        adult                              belongs_to_collection     budget  \
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...   58000000
# 68     False  {'id': 43563, 'name': 'Friday Collection', 'po...    3500000
# 69     False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...   19000000
# 153    False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...    2000000
# 178    False  {'id': 286162, 'name': 'Power Rangers Collecti...   15000000
# ...      ...                                                ...        ...
# 44009  False  {'id': 86066, 'name': 'Despicable Me Collectio...   80000000
# 44274  False  {'id': 173710, 'name': 'Planet of the Apes (Re...  152000000
# 44674  False  {'id': 476961, 'name': 'Goon Collection', 'pos...          0
# 44842  False  {'id': 8650, 'name': 'Transformers Collection'...  260000000
# 753    False  {'id': 303969, 'name': 'Martin Scorsese’s Worl...          0
#
#                                                   genres  \
# ...

# %%
df.shape
# Out:
# (693, 24)

# %%
df_en.shape
# Out:
# (610, 24)

# %%
df_wo.shape
# Out:
# (1, 24)

# %%
df_merge_ew.shape
# Out:
# (611, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 693 entries, 9 to 45029
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  693 non-null    object
#  1   belongs_to_collection  693 non-null    object
#  2   budget                 693 non-null    object
#  3   genres                 693 non-null    object
#  4   homepage               693 non-null    object
#  5   id                     693 non-null    object
#  6   imdb_id                693 non-null    object
#  7   original_language      693 non-null    object
#  8   original_title         693 non-null    object
#  9   overview               693 non-null    object
#  10  popularity             693 non-null    object
#  11  poster_path            693 non-null    object
#  12  production_companies   693 non-null    object
#  13  production_countries   693 non-null    object
# ...

# %%
df_sort = df.sort_values(by = ["id"])

# %%
df_sort
# Out:
#        adult                              belongs_to_collection     budget  \
# 17977  False  {'id': 98513, 'name': 'Behind Enemy Lines Coll...          0
# 6740   False  {'id': 96472, 'name': 'Brother Bear Collection...  100000000
# 20269  False  {'id': 108804, 'name': 'Outpost Collection', '...    3000000
# 588    False  {'id': 153010, 'name': 'Beauty and the Beast C...   25000000
# 11435  False  {'id': 43220, 'name': 'National Lampoon’s Van ...          0
# ...      ...                                                ...        ...
# 35536  False  {'id': 98448, 'name': 'Thou Shalt Laugh Collec...          0
# 23897  False  {'id': 401562, 'name': 'Teenage Mutant Ninja T...  125000000
# 20439  False  {'id': 146136, 'name': 'Armour of God Collecti...   48000000
# 2215   False  {'id': 348843, 'name': 'Vampires Collection', ...   20000000
# 26558  False  {'id': 86311, 'name': 'The Avengers Collection...  280000000
#
#                                                   genres  \
# ...

# %%
df_transpose = df.transpose()
df_transpose
# Out:
#                                                                    9      \
# adult                                                              False
# belongs_to_collection  {'id': 645, 'name': 'James Bond Collection', '...
# budget                                                          58000000
# genres                 [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# homepage                    http://www.mgm.com/view/movie/757/Goldeneye/
# id                                                                   710
# imdb_id                                                        tt0113189
# original_language                                                     en
# original_title                                                 GoldenEye
# overview               James Bond must unmask the mysterious head of ...
# popularity                                                     14.686036
# poster_path                             /5c0ovjT41KnYIHYuF4AWsTe3sKh.jpg
# ...

# %%
df_melt = pd.melt(df,id_vars=["id","original_language"],var_name="Metric",value_name="Value")
df_melt
# Out:
#            id original_language      Metric   Value
# 0         710                en       adult   False
# 1       10634                en       adult   False
# 2         755                en       adult   False
# 3        5894                en       adult   False
# 4        9070                en       adult   False
# ...       ...               ...         ...     ...
# 15241  281338                en  vote_count  1675.0
# 15242  336890                en  vote_count    35.0
# 15243   10991                ja  vote_count   144.0
# 15244  335988                en  vote_count  1440.0
# 15245  417489                fr  vote_count     5.0
#
# [15246 rows x 4 columns]

# %%
df_cast = pd.pivot_table(df,index=["id","original_language"],values="original_title",aggfunc="first")
df_cast_title = pd.pivot_table(df,index=["id","original_language"],values="spoken_languages",aggfunc="first")
dfr_cast_final = pd.concat([df_cast,df_cast_title],axis = 1)

# %%
dfr_cast_final
# Out:
#                                                original_title  \
# id     original_language
# 10005  en                 Behind Enemy Lines II: Axis of Evil
# 10009  en                                        Brother Bear
# 100183 en                                  Outpost: Black Sun
# 10020  en                                Beauty and the Beast
# 10032  en                       Van Wilder 2: The Rise of Taj
# ...                                                       ...
# 98440  en                                  Thou Shalt Laugh 3
# 98566  en                        Teenage Mutant Ninja Turtles
# 98567  cn                                      Chinese Zodiac
# 9945   en                                            Vampires
# 99861  en                             Avengers: Age of Ultron
#
#                                                            spoken_languages
# id     original_language
# 10005  en                 [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...
